# %% [markdown]
# ### Các loại applications:
# 1. Robotics, autonomous machinery
# 2. Computer Vision
# 3. Anomaly detection
# 4. IoT systems & data platforms
# 5. Perception system
# 6. Optimization
# 7. Natural Language Processing
# 8. Personalization
# 9. Business Intelligence
#
# ## AI application components
# - Data -> AI component -> Result / Output
# - Collect / Create -> Choose model -> Visualize
# ![image.png](attachment:image.png)
#
# => Can use external AI Service (no-code, api)
# - vd:
#     - takomo.ai: api? no-code
#     - hugging face:
#         - online community of machine learning experts
#         - tons of thousands models and some of them are hosted => can access through API
#     - YOLO: image detection
#     -
# ### What needs to have if want to build app?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Problem of your own trained model
# - takes time
# - computational power
# - no enough data
# - turning model
#
# problems of external AI services
# - cost
# - latency
# - data used to train their models does not have their species -> could not predict correctly

# %% [markdown]
# ### 3 ways to make AI apps: simple, intermediate, advanced
# 1. get no-code to call api to pre-trained model
# 2. fine tuning, when we have some great dataset available for our task and we have an optimal situation in this machine larning problem
# 3. deep learning: tuning
#     - data augmentation
#     - choose loose function

# %% [markdown]
# ### What is the task that is the most important and time-consuming?
# - prepare data: label, resize
# - augmentation: very carefull, what is the good combination. Because it's very easy to do an Overkill with these because we have so many of them freely available and some of the very big combination of them can actually make the problem even worse => do it slowly until find the optimal augmentation
