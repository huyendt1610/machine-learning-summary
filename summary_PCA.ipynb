# %% [markdown]
# - Phương pháp giảm chiều dữ liệu:
#     - PCA - Principal Component Analysis - Phân tích thành phần chính (giữ lại các chiều theo trị riêng mà có biến thiên nhiều nhất ) -> sao cho tổng lượng thông tin đc giữ lạ là max (tổng lượng phương sai)
#     ![image.png](attachment:image.png)
#     - SVD - Singular Value Decomposition - Phân rã theo trị riêng -> lấy 1 số trị riêng mà có thể xấp xỉ giá trị ma trận ban đầu, loại bỏ 1 số -> giảm chiều (xấp xỉ A bởi ma trận có rank nhỏ hơn A)
#     $$
#     A = U_k * \Sigma_k * V_k^T
#     $$
#     - PCA là 1 trường hợp đặc biệt của SVD
#     - Có thể áp dụng SVD trong bài toán Recommendation Systems
