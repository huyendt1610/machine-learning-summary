# %% [markdown]
# ### Python
#
# - *arg: ko gioi han so luong tham so, list, dict
# - **kwarg: keyword args (key=value)
# - *var1: decompose var1 to list, dict
# - **var1: decompose var1 to key=value
# - /: func(only position arg, /, either position/keyword arg)
# - '*': func(either position/keyword arg, *, only keyword arg)
#
# ### scikit-learn
#
# intercept_: dấu gạch dưới mô tả dữ liệu chỉ có sau khi mô hình đã
